# %%
from datetime import datetime ,timedelta
import time
from collections import namedtuple
import pandas as pd
import requests
import matplotlib.pyplot as plt

# %%
df=pd.read_json('http://api.wunderground.com/api/85fc487808325a74/conditions/q/CA/San_Francisco.json')

# %%
df
# Out:
#                                                        current_observation  \
# UV                                                                     0.0
# dewpoint_c                                                               8
# dewpoint_f                                                              46
# dewpoint_string                                                 46 F (8 C)
# display_location         {'full': 'San Francisco, CA', 'city': 'San Fra...
# estimated                                                               {}
# features                                                               NaN
# feelslike_c                                                             10
# feelslike_f                                                             50
# feelslike_string                                               50 F (10 C)
# forecast_url             http://www.wunderground.com/US/CA/San_Francisc...
# heat_index_c                                                            NA
# heat_index_f                                                            NA
# heat_index_string                                                       NA
# history_url              http://www.wunderground.com/weatherstation/WXD...
# icon                                                                 clear
# icon_url                             http://icons.wxug.com/i/c/k/clear.gif
# image                    {'url': 'http://icons.wxug.com/graphics/wu2/lo...
# local_epoch                                                     1511883641
# local_time_rfc822                          Tue, 28 Nov 2017 07:40:41 -0800
# local_tz_long                                          America/Los_Angeles
# local_tz_offset                                                      -0800
# local_tz_short                                                         PST
# nowcast
# ob_url                   http://www.wunderground.com/cgi-bin/findweathe...
# observation_epoch                                               1511883638
# observation_location     {'full': 'SOMA, San Francisco, California', 'c...
# observation_time                  Last Updated on November 28, 7:40 AM PST
# observation_time_rfc822                    Tue, 28 Nov 2017 07:40:38 -0800
# precip_1hr_in                                                         0.00
# precip_1hr_metric                                                        0
# precip_1hr_string                                          0.00 in ( 0 mm)
# precip_today_in                                                       0.00
# precip_today_metric                                                      0
# precip_today_string                                         0.00 in (0 mm)
# pressure_in                                                          30.14
# pressure_mb                                                           1020
# pressure_trend                                                           +
# relative_humidity                                                      88%
# solarradiation                                                          35
# station_id                                                     KCASANFR131
# temp_c                                                                 9.7
# temp_f                                                                49.5
# temperature_string                                          49.5 F (9.7 C)
# termsofService                                                         NaN
# version                                                                NaN
# visibility_km                                                         16.1
# visibility_mi                                                         10.0
# weather                                                              Clear
# wind_degrees                                                         -9999
# wind_dir                                                             North
# wind_gust_kph                                                            0
# wind_gust_mph                                                            0
# wind_kph                                                                 0
# wind_mph                                                                 0
# wind_string                                                           Calm
# windchill_c                                                             10
# windchill_f                                                             50
# windchill_string                                               50 F (10 C)
#
#                                                                   response
# UV                                                                     NaN
# dewpoint_c                                                             NaN
# dewpoint_f                                                             NaN
# dewpoint_string                                                        NaN
# display_location                                                       NaN
# estimated                                                              NaN
# features                                                 {'conditions': 1}
# feelslike_c                                                            NaN
# feelslike_f                                                            NaN
# feelslike_string                                                       NaN
# forecast_url                                                           NaN
# heat_index_c                                                           NaN
# heat_index_f                                                           NaN
# heat_index_string                                                      NaN
# history_url                                                            NaN
# icon                                                                   NaN
# icon_url                                                               NaN
# image                                                                  NaN
# local_epoch                                                            NaN
# local_time_rfc822                                                      NaN
# local_tz_long                                                          NaN
# local_tz_offset                                                        NaN
# local_tz_short                                                         NaN
# nowcast                                                                NaN
# ob_url                                                                 NaN
# observation_epoch                                                      NaN
# observation_location                                                   NaN
# observation_time                                                       NaN
# observation_time_rfc822                                                NaN
# precip_1hr_in                                                          NaN
# precip_1hr_metric                                                      NaN
# precip_1hr_string                                                      NaN
# precip_today_in                                                        NaN
# precip_today_metric                                                    NaN
# precip_today_string                                                    NaN
# pressure_in                                                            NaN
# pressure_mb                                                            NaN
# pressure_trend                                                         NaN
# relative_humidity                                                      NaN
# solarradiation                                                         NaN
# station_id                                                             NaN
# temp_c                                                                 NaN
# temp_f                                                                 NaN
# temperature_string                                                     NaN
# termsofService           http://www.wunderground.com/weather/api/d/term...
# version                                                                0.1
# visibility_km                                                          NaN
# visibility_mi                                                          NaN
# weather                                                                NaN
# wind_degrees                                                           NaN
# wind_dir                                                               NaN
# wind_gust_kph                                                          NaN
# wind_gust_mph                                                          NaN
# wind_kph                                                               NaN
# wind_mph                                                               NaN
# wind_string                                                            NaN
# windchill_c                                                            NaN
# windchill_f                                                            NaN
# windchill_string                                                       NaN

# %%
df.columns
# Out:
# Index(['current_observation', 'response'], dtype='object')

# %%
df.info()
